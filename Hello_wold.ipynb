# %% [markdown]
# <a href="https://colab.research.google.com/github/alicemariecr/pa-1c--grupo-A/blob/main/Hello_wold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello wold!!")
# Out:
# Hello wold!!

# %%
idade = 15     #int
altura = 1.66    #float
numero_complexo = 2 + 3j
esta_chovendo = false

# %%
#area

lado = 10
quadrado = lado * lado
print (f"total da área do quadrado: {quadrado}" )
# Out:
# total da área do quadrado: 100

# %%
#area

largura = 5
altura = 4
area = largura * altura
print (f"total da área: {area}" )
# Out:
# total da área: 20

# %%
#area

largura = float(input("A medida da largura: "))
altura = float(input("A medida da altura: "))
area = largura * altura
print(f"total da área: {area}")
# Out:
# A medida da largura: 6
# A medida da altura: 2
# total da área: 12.0

# %%
#media

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite sua segunda nota: "))
nota3 = float(input("Digite sua terceira nota: "))
nota4 = float(input("Digite sua quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4)/4
print (media)
# Out:
# Digite a primeira nota: 10
# Digite sua segunda nota: 8.5
# Digite sua terceira nota: 9
# Digite sua quarta nota: 9.5
# 9.25

# %%
#dobro

numero1 = float(input("Digite o número: "))
dobro = numero1 * 2
print (dobro)
# Out:
# Digite o número: 2
# 4.0

# %% [markdown]
# Aula do dia 16/03 👇🏼

# %%
#fazer um cadastro simples, com o nome do usuario e a idade.

nome = str(input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))
print (f"Olá {nome}, seja bem vindo(a)!")
print (f"Você tem {idade} anos, certo?")
# Out:
# Digite seu nome: alice
# Digite sua idade: 15
# Olá alice, seja bem vindo(a)!
# Você tem 15 anos, certo?

# %%
#Fazer um programa que converte celsius para fahrenheit

temperatura = float(input("Digite a temperatura em Celsius: "))
calculo = (temperatura * 9/5) + 32
print (f"A temperatura em farenheit é: {calculo}")
# Out:
# Digite a temperatura em Celsius: 25
# A temperatura em farenheit é: 77.0

# %%
#soma de dois numeros
a = float(input("Digite o primeirop número: "))
b = float(input("Digite o segundo número: "))
soma = a + b
print ("----------SOMA----------")
print("")
print(f"A soma dos números é igual: {soma}")
print("")
print("-------------------------")
# Out:
# Digite o primeirop número: 2
# Digite o segundo número: 4
# ----------SOMA----------
#
# A soma dos números é igual: 6.0
#
# -------------------------

# %%
#calculadora
a = float(input("Digite o primeirop número: "))
b = float(input("Digite o segundo número: "))
soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a/b
print("---------------SOMA---------------")
print(f"A soma dos números é igual: {soma}")
print("----------------------------------")
print("")

print("------------Subtração------------")
print(f"A subtração dos números é: {subtracao}")
print("---------------------------------")
print("")

print("-----------Multiplicação-----------")
print(f"A multiplicação dos números é: {multiplicacao}")
print("-----------------------------------")
print("")

print("------------Divisão------------")
print(f"A divisão dos números é: {divisao}")
print("-------------------------------")
print("")
# Out:
# Digite o primeirop número: 100
# Digite o segundo número: 10
# ---------------SOMA---------------
# A soma dos números é igual: 110.0
# ----------------------------------
#
# ------------Subtração------------
# A subtração dos números é: 90.0
# ---------------------------------
#
# -----------Multiplicação-----------
# A multiplicação dos números é: 1000.0
# -----------------------------------
#
# ------------Divisão------------
# A divisão dos números é: 10.0
# -------------------------------

# %%
Aula de 23/03/2026 👇🏼

# %%
#comparador de numeros
a = int(input("Digite um número: "))
b = int(input("Digite um número: "))
if a > b:
  print(f"{a} é maior que {b}")
else:
   print(f"{b} é maior que {a}")
# Out:
# Digite um número: 10
# Digite um número: 30
# 30 é maior que 10

# %%
#escreva um programa que confira se a pessoa é maior de 18
nome = str(input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))

if idade > 18:
  print(f"{nome}, você é maiopr de idade.")
else:
  print(f"{nome}, você é menor de idade.")
# Out:
# Digite seu nome: alice
# Digite sua idade: 15
# alice, você é menor de idade.

# %%
#par ou impar
numero = int(input("Digite o primeiro número: "))
divisao = numero % 2
if divisao == 0:
  print("O número é par.")
else:
  print("O número é impar.")
# Out:
# Digite o primeiro número: 20
# O número é par.

# %%
#programa que so entra com a senha 1234
senha = int(input("Digite sua senha: "))
if senha == 1234:
  print("Acesso permitido!")
else:
  print("Acesso negado, digite a senha novamente.")
# Out:
# Digite sua senha: 1234
# Acesso permitido!

# %%
#veja se o numero é maior que 10
numero = int(input("Digite o número: "))
if numero >= 10:
  print("O número é maior ou igual que 10.")
else:
  print("O número é menor que 10.")
# Out:
# Digite o número: 5
# O número é menor que 10.

# %%
#peca o valor da compra e se for maior que 100 aplique um desconto de 10%
compra = int(input("Digite o valor total de sua compra: "))
conta = compra - (compra * 0.10)
if compra > 100:
  print(f"Você tem 10% de desconto! O valor total passa a ser {conta}")
else:
  print("Você não tem desconto.")
# Out:
# Digite o valor total de sua compra: 120
# Você tem 10% de desconto! O valor total passa a ser 108.0
