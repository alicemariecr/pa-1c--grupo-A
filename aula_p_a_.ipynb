# %% [markdown]
# <a href="https://colab.research.google.com/github/alicemariecr/pa-1c--grupo-A/blob/main/aula_p_a_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula dia 30/03👇🏼

# %%
#calculadora simples
print("CALCULADORA SIMPLES ")
print("")
print("------MENU------")
a = float(input("Digite o primeirop número: "))
b = float(input("Digite o segundo número: "))
soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a/b
print("")
print("---------------SOMA---------------")
print(f"A soma dos números é igual: {soma}")
print("----------------------------------")
print("")

print("------------Subtração------------")
print(f"A subtração dos números é: {subtracao}")
print("---------------------------------")
print("")

print("-------------Multiplicação-------------")
print(f"A multiplicação dos números é: {multiplicacao}")
print("---------------------------------------")
print("")

print("------------Divisão------------")
print(f"A divisão dos números é: {divisao}")
print("-------------------------------")
print("")
# Out:
# CALCULADORA SIMPLES
#
# ------MENU------
# Digite o primeirop número: 100
# Digite o segundo número: 10
#
# ---------------SOMA---------------
# A soma dos números é igual: 110.0
# ----------------------------------
#
# ------------Subtração------------
# A subtração dos números é: 90.0
# ---------------------------------
#
# -------------Multiplicação-------------
# A multiplicação dos números é: 1000.0
# ---------------------------------------
#
# ------------Divisão------------
# A divisão dos números é: 10.0
# -------------------------------

# %%
#calculadora
print("|------------------------------|")
print("|          CALCULADORA         |")
print("|                              |")
print("|-------------Menu-------------|")
print("|                              |")
print("| Soma = 1                     |")
print("| Subtração = 2                |")
print("| Multiplicação = 3            |")
print("| Divisão = 4                  |")
print("|------------------------------|")
numero = int(input("Digite qual das operações você quer usar: "))
print("")

a = int(input("Digite o primeiro número: "))
b = int(input("Digite o segundo número: "))
print("")

if numero == 1:
  print(f"A soma dos números é igual: {a + b}")
if numero == 2:
  print(f"A subtração dos números é igual: {a - b}")
if numero == 3:
  print(f"A multiplicação dos números é igual: {a * b}")
if numero == 4:
  print(f"A divisão dos números é igual: {a / b}")
# Out:
# |------------------------------|
# |          CALCULADORA         |
# |                              |
# |-------------Menu-------------|
# |                              |
# | Soma = 1                     |
# | Subtração = 2                |
# | Multiplicação = 3            |
# | Divisão = 4                  |
# |------------------------------|
# Digite qual das operações você quer usar: 1
#
# Digite o primeiro número: 10
# Digite o segundo número: 10
#
# A soma dos números é igual: 20

# %%
#aula dia 27/04

# %%
#for é usado para a repetiçao

for i in range (1,6): #aqui é para contar do 1 ao 5
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#para fazer essa sequencia ao contrario, vc usa o numero q vc usou dentro dos parenteses -(menos) a variavel i ouu se quiser q apareca o zero na contagem igual eu fiz, coloca o numero maior na parte de cima do codigo e em baixo vc coloca um  numero menor

for i in range (6):
  print (5-i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#programa q mostra os numeros pares de 0 a 10

for i in range(0,11,2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#outro jeito de mostrar os numeros pares de 0 a 10

for i in range (11):

  if i % 2 == 0:
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#escrever um programa que o usuario digita um numero de 1 a 10 e imprime a tabuada desse numero

numero = int(input("Digite um número de 1 a 10: "))
for i in range(1, 11):
  resultado = numero * i
  print(f"{numero} X {i} = {resultado}" )
# Out:
# Digite um número de 1 a 10: 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
04/05/2026👇🏼

# %%
#escreva um programa que o usuario digita o numero e o programa imprimi do 0 ate o numero
num = int(input("Digite um número: "))
for i in range(num + 1):
  print(i)
# Out:
# Digite um número: 5
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#escreva um programa que o usuario digita o numero e o programa imprimi em ordem decrescente
numero = int(input("Digite um número: "))
for i in range(numero, -1,-1):
  print(i)
# Out:
# Digite um número: 5
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#peca um numero mostre os numeros pares ate chegar nesse numero
num = int(input("Digite um número: "))
for i in range(0, numero + 1,2):
  print(i)
# Out:
# Digite um número: 10
# 0
# 2
# 4

# %%
#peca um numero e calcule a soma de 1 ate o numero
num = int(input("Digite um número: "))
soma = num*(numero+1)//2
print(f"a soma é {soma}")
# Out:
# Digite um número: 5
# a soma é 15

# %%
#peca um palavra e conte as letras
palavra = input("Digite uma palavra: ")
quantidade = 0
for i in range(len(palavra)):
  quantidade += 1
print(f"a qauntidade de letras é {quantidade}")
# Out:
# Digite um número: alice
# a qauntidade de letras é 5

# %%
#peca uma palavra e conte as vogais
word = input("Digite uma palavra: ")
vowel_count = sum(1 for char in word.lower() if char in "aeiou")
print(f"A palavra {word} tem {vowel_count} vogais.")
# Out:
# Digite uma palavra: alice
# A palavra alice tem 3 vogais.

# %%
#peca para o usuario digitar 5 numeros e informar o maior
maior = int(input("Digite um número: "))
for i in range(4):
  num = int(input("Digite um número: "))
  if num > maior:
    maior = num
print(f"O maior numero é {maior}")
# Out:
# Digite um número: 1
# Digite um número: 2
# Digite um número: 3
# Digite um número: 4
# Digite um número: 5
# O maior numero é 5
