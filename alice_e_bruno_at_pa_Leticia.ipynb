# %% [markdown]
# <a href="https://colab.research.google.com/github/alicemariecr/pa-1c--grupo-A/blob/main/alice_e_bruno_at_pa_Leticia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1 – Criando variáveis
# Crie as variáveis abaixo e mostre o valor e o tipo de cada uma usando print() e type():
# • nome
# • idade
# • altura
# • nota
# • cidade

# %%
nome = "Bruno"
idade = 16
altura = 1.71
nota = "R"
cidade = "Mauá"

print(f"Nome: {nome}")
print(f"Idade: {idade}")
print(f"Altura: {altura}")
print(f"Nota: {nota}")
print(f"Cidade: {cidade}")
# Out:
# Nome: Bruno
# Idade: 16
# Altura: 1.71
# Nota: R
# Cidade: Mauá

# %% [markdown]
# Exercício 2 – Contas básicas
# Escreva um programa que:
# • Guarde as notas 7.5, 8.0 e 6.5
# • Calcule a média
# • Mostre a média na tela

# %%
n1 = 7.5
n2 = 8
n3 = 6.5
calc = (n1 + n2 + n3)/3
print(f"Sua media é: {calc}")
# Out:
# Sua media é: 7.333333333333333

# %% [markdown]
# Exercício 3 – Conversões
# Faça as conversões e mostre o resultado:
# Python
# texto1 = "20"
# texto2 = "3.5"
# numero = 8
# a) Transforme texto1 em inteiro e some com 10 b) Transforme texto2 em real e
# multiplique por 2 c) Transforme número em texto e junte com a palavra "anos"

# %%
texto1 = '20'
texto2 = '3.5'
numero = 8

texto1 = int(texto1)
soma = texto1 + 10
print(soma)
print(type(soma))
print(" ")

texto2 = float(texto2)
mult = texto2 * 2
print(f'R$: {texto2}')
print(type(mult))
print(" ")

numero = str(numero)
print(f"{numero} anos")
print(type(numero))
# Out:
# 30
# <class 'int'>
#
# R$: 3.5
# <class 'float'>
#
# 8 anos
# <class 'str'>
